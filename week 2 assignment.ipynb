# %%
energies = [50, 60, 70, 80, 90]

print("Energies list:", energies)

energies.append(100)

print("After append:", energies)

energy_dict = {
    "Mon": 50,
    "Tue": 60,
    "Wed": 70
}

print("Energy dict:", energy_dict)

energy_dict["Thu"] = 80

print("After add Thu:", energy_dict)

sources = {"Solar", "Wind", "Solar"}

print("Unique sources:", sources)

sources.add("Coal")

print("After add Coal:", sources)
# Out:
# Energies list: [50, 60, 70, 80, 90]
# After append: [50, 60, 70, 80, 90, 100]
# Energy dict: {'Mon': 50, 'Tue': 60, 'Wed': 70}
# After add Thu: {'Mon': 50, 'Tue': 60, 'Wed': 70, 'Thu': 80}
# Unique sources: {'Wind', 'Solar'}
# After add Coal: {'Coal', 'Wind', 'Solar'}
